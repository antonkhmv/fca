# %% [markdown]
# # Prepare data

# %%
input_dir = "./data"
raw_input_dir = "."

# %%
import pandas as pd
import numpy as np
import os

df_raw = pd.read_csv(os.path.join(raw_input_dir, "student-performance-data/student_data.csv"))
df_raw = df_raw.drop(["G1", "G2"], axis=1)

with pd.option_context('display.max_columns', 400):
    display(df_raw.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# 0         no     yes    yes       no       no       4         3      4     1
# 1         no      no    yes      yes       no       5         3      3     1
# 2         no     yes    yes      yes       no       4         3      2     2
# 3        yes     yes    yes      yes      yes       3         2      2     1
# 4         no     yes    yes       no       no       4         3      2     1
#
#    Walc  health  absences  G3
# 0     1       3         6   6
# 1     1       3         4   6
# 2     3       3        10  10
# 3     1       5         2  15
# 4     2       5         4  10

# %%
from fca_utils import common_prepare

students_target_variable = "G3"
students_bool_cols = ["schoolsup", "famsup", "paid", "activities", "nursery", "higher", "internet", "romantic"]
students_int_cols = ["age", "Medu", "Fedu", "traveltime", "studytime", "failures", "famrel", "freetime", "goout", "Dalc", "Walc", "health", "absences"]
students_cat_cols = ["school", "sex", "address", "famsize", "Pstatus", "Mjob", "Fjob", "reason", "guardian"]

move_cols_to_bool = ["sex", "address", "school", "famsize", "Pstatus"]

for col in move_cols_to_bool:
    students_bool_cols.append(col) 
    students_cat_cols.remove(col)

df = common_prepare(df_raw, 
                    bool_columns=students_bool_cols, 
                    categorical_cols=students_cat_cols, 
                    ordinal_columns=students_int_cols,
                    y_target=students_target_variable,
                    bool_subs={'F':1, 'M':0, 'yes':1, 'no':0, 'GT3': 1, 'LE3': 0, 'GP': 1, 'MS': 0, 'U': 1, 'R': 0, 'A': 1, 'T': 0}
) 

df.head()
# Out:
#    G3  age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0   0   18     4     4           2          2         0       4         3
# 1   0   17     1     1           1          2         0       5         3
# 2   0   15     1     1           1          2         3       4         3
# 3   1   15     4     2           1          3         0       3         2
# 4   0   16     3     3           1          2         0       4         3
#
#    goout  ...  activities  nursery  higher  internet romantic sex address  \
# 0      4  ...           0        1       1         0        0   1       1
# 1      3  ...           0        0       1         1        0   1       1
# 2      2  ...           0        1       1         1        0   1       1
# 3      2  ...           1        1       1         1        1   1       1
# 4      2  ...           0        1       1         0        0   1       1
#
#   school  famsize  Pstatus
# 0      1        1        1
# 1      1        1        0
# 2      1        0        0
# 3      1        1        0
# 4      1        1        0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   G3          395 non-null    int64
#  1   age         395 non-null    int64
#  2   Medu        395 non-null    int64
#  3   Fedu        395 non-null    int64
#  4   traveltime  395 non-null    int64
#  5   studytime   395 non-null    int64
#  6   failures    395 non-null    int64
#  7   famrel      395 non-null    int64
#  8   freetime    395 non-null    int64
#  9   goout       395 non-null    int64
#  10  Dalc        395 non-null    int64
#  11  Walc        395 non-null    int64
#  12  health      395 non-null    int64
#  13  absences    395 non-null    int64
#  14  Mjob        395 non-null    object
#  15  Fjob        395 non-null    object
#  16  reason      395 non-null    object
#  17  guardian    395 non-null    object
#  18  schoolsup   395 non-null    int64
#  19  famsup      395 non-null    int64
#  20  paid        395 non-null    int64
#  21  activities  395 non-null    int64
#  22  nursery     395 non-null    int64
#  23  higher      395 non-null    int64
#  24  internet    395 non-null    int64
#  25  romantic    395 non-null    int64
#  26  sex         395 non-null    int64
#  27  address     395 non-null    int64
#  28  school      395 non-null    int64
#  29  famsize     395 non-null    int64
#  30  Pstatus     395 non-null    int64
# dtypes: int64(27), object(4)
# memory usage: 95.8+ KB

# %% [markdown]
# # Binary FCA

# %%
from itertools import product
import fcalc

# %%
from fca_utils import build_configs

param_grid = {
    'onehot_cols': [students_cat_cols],
    'factorize_cols': [[]],
    'qcut_cols': [
        {},
        dict.fromkeys(students_int_cols, 2),
        dict.fromkeys(students_int_cols, 4),
        dict.fromkeys(students_int_cols, 10),
    ],
    'binarize_all': [True],
}

configs = build_configs(param_grid)

methods = [
    'standard',
    'standard-support',
    'ratio-support'
]

# %%
from fca_utils import grid_search

best_binary_config, best_binary_intersecs, best_binary_score = grid_search(
    df,
    fcalc.classifier.BinarizedBinaryClassifier,
    y_target=students_target_variable,
    n_folds=5,
    methods=methods,
    configs=configs,
)
# Out:
# Fitting 12 configurations
# 1
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': True}
# method='standard'
# f1_macro (mean)=0.558628587781754
# f1_cls_1=[0.4827586206896552, 0.36363636363636365, 0.3529411764705882, 0.3939393939393939, 0.5]
# f1_cls_0=[0.7, 0.7543859649122807, 0.6915887850467289, 0.5652173913043479, 0.7818181818181819]
# f1_macro=[0.5913793103448276, 0.5590111642743222, 0.5222649807586586, 0.4795783926218709, 0.6409090909090909]
#
# 2
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': True}
# method='standard'
# f1_macro (mean)=0.5173390354715953
# f1_cls_1=[0.4666666666666666, 0.15789473684210525, 0.19999999999999998, 0.3934426229508197, 0.41860465116279066]
# f1_cls_0=[0.673469387755102, 0.7333333333333333, 0.7288135593220338, 0.6185567010309279, 0.7826086956521738]
# f1_macro=[0.5700680272108843, 0.44561403508771924, 0.4644067796610169, 0.5059996619908738, 0.6006066734074822]
#
# 3
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': True}
# method='standard'
# f1_macro (mean)=0.5450464607267488
# f1_cls_1=[0.5396825396825397, 0.34782608695652173, 0.4, 0.3384615384615385, 0.35555555555555557]
# f1_cls_0=[0.6947368421052632, 0.7321428571428572, 0.7610619469026548, 0.5376344086021505, 0.743362831858407]
# f1_macro=[0.6172096908939014, 0.5399844720496895, 0.5805309734513274, 0.4380479735318445, 0.5494591937069813]
#
# 4
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 10, 'Medu': 10, 'Fedu': 10, 'traveltime': 10, 'studytime': 10, 'failures': 10, 'famrel': 10, 'freetime': 10, 'goout': 10, 'Dalc': 10, 'Walc': 10, 'health': 10, 'absences': 10}, 'binarize_all': True}
# method='standard'
# f1_macro (mean)=0.553182265265473
# f1_cls_1=[0.5245901639344263, 0.35555555555555557, 0.3673469387755102, 0.3225806451612903, 0.4799999999999999]
# f1_cls_0=[0.7010309278350516, 0.743362831858407, 0.7155963302752295, 0.5625, 0.7592592592592592]
# f1_macro=[0.6128105458847389, 0.5494591937069813, 0.5414716345253698, 0.44254032258064513, 0.6196296296296295]
#
# 5
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': True}
# method='standard-support'
# f1_macro (mean)=0.5250673904643931
# f1_cls_1=[0.574468085106383, 0.5230769230769231, 0.5128205128205128, 0.5806451612903226, 0.47761194029850745]
# f1_cls_0=[0.37499999999999994, 0.6666666666666666, 0.525, 0.4, 0.6153846153846154]
# f1_macro=[0.4747340425531915, 0.5948717948717949, 0.5189102564102563, 0.4903225806451613, 0.5464982778415615]
#
# 6
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': True}
# method='standard-support'
# f1_macro (mean)=0.5592876790130795
# f1_cls_1=[0.4444444444444444, 0.3181818181818182, 0.34782608695652173, 0.5428571428571428, 0.43478260869565216]
# f1_cls_0=[0.631578947368421, 0.7368421052631577, 0.7321428571428571, 0.6363636363636365, 0.7678571428571429]
# f1_macro=[0.5380116959064327, 0.5275119617224879, 0.5399844720496894, 0.5896103896103897, 0.6013198757763976]
#
# 7
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': True}
# method='standard-support'
# f1_macro (mean)=0.5336204269196798
# f1_cls_1=[0.5, 0.43636363636363634, 0.4918032786885246, 0.5060240963855421, 0.39999999999999997]
# f1_cls_0=[0.5365853658536586, 0.6990291262135924, 0.6804123711340205, 0.45333333333333337, 0.6326530612244897]
# f1_macro=[0.5182926829268293, 0.5676963812886143, 0.5861078249112726, 0.47967871485943775, 0.5163265306122449]
#
# 8
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 10, 'Medu': 10, 'Fedu': 10, 'traveltime': 10, 'studytime': 10, 'failures': 10, 'famrel': 10, 'freetime': 10, 'goout': 10, 'Dalc': 10, 'Walc': 10, 'health': 10, 'absences': 10}, 'binarize_all': True}
# method='standard-support'
# f1_macro (mean)=0.552904689858386
# f1_cls_1=[0.5617977528089889, 0.5217391304347826, 0.5789473684210527, 0.5777777777777778, 0.5294117647058824]
# f1_cls_0=[0.43478260869565216, 0.6292134831460675, 0.6097560975609756, 0.44117647058823534, 0.6444444444444445]
# f1_macro=[0.49829018075232057, 0.575476306790425, 0.5943517329910142, 0.5094771241830066, 0.5869281045751634]
#
# 9
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': True}
# method='ratio-support'
# f1_macro (mean)=0.520595263977644
# f1_cls_1=[0.6213592233009708, 0.6341463414634146, 0.6, 0.6666666666666667, 0.5]
# f1_cls_0=[0.2909090909090909, 0.6052631578947368, 0.31034482758620696, 0.4406779661016949, 0.5365853658536586]
# f1_macro=[0.45613415710503086, 0.6197047496790757, 0.45517241379310347, 0.5536723163841808, 0.5182926829268293]
#
# 10
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': True}
# method='ratio-support'
# f1_macro (mean)=0.5535236514249727
# f1_cls_1=[0.5405405405405405, 0.27906976744186046, 0.5151515151515151, 0.6304347826086957, 0.44067796610169496]
# f1_cls_0=[0.5952380952380952, 0.7304347826086957, 0.6521739130434783, 0.4848484848484849, 0.6666666666666667]
# f1_macro=[0.5678893178893178, 0.5047522750252781, 0.5836627140974967, 0.5576416337285903, 0.5536723163841808]
#
# 11
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': True}
# method='ratio-support'
# f1_macro (mean)=0.5245030486812531
# f1_cls_1=[0.6105263157894737, 0.5428571428571429, 0.5977011494252874, 0.6346153846153845, 0.4657534246575342]
# f1_cls_0=[0.4126984126984127, 0.6363636363636364, 0.5070422535211269, 0.29629629629629634, 0.5411764705882354]
# f1_macro=[0.5116123642439432, 0.5896103896103897, 0.5523717014732071, 0.46545584045584043, 0.5034649476228847]
#
# 12
# classifier=<class 'fcalc.classifier.BinarizedBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 10, 'Medu': 10, 'Fedu': 10, 'traveltime': 10, 'studytime': 10, 'failures': 10, 'famrel': 10, 'freetime': 10, 'goout': 10, 'Dalc': 10, 'Walc': 10, 'health': 10, 'absences': 10}, 'binarize_all': True}
# method='ratio-support'
# f1_macro (mean)=0.4940178716604463
# f1_cls_1=[0.6138613861386139, 0.5301204819277109, 0.5833333333333334, 0.6274509803921569, 0.5454545454545454]
# f1_cls_0=[0.31578947368421056, 0.48, 0.3548387096774194, 0.3214285714285714, 0.5679012345679013]
# f1_macro=[0.4648254299114122, 0.5050602409638554, 0.46908602150537637, 0.4744397759103641, 0.5566778900112234]

# %%
from collections import Counter

print("Best config for binary")
print(best_binary_config)
print()
print("Most important intersections (positive):")
print("\n".join(map(str, best_binary_intersecs[0].most_common(10))))
print()
print("Most important intersections (negative):")
print("\n".join(map(str, best_binary_intersecs[1].most_common(10))))
print()
print("Best f1_macro score for binary")
print(best_binary_score)
# Out:
# Best config for binary
# ('standard-support', {'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': True})
#
# Most important intersections (positive):
# (('nursery', 'higher', 'internet', 'address', 'school', 'famsize', 'Fedu'), 63)
# (('nursery', 'higher', 'internet', 'address', 'school', 'famsize', 'Mjob_other', 'Fjob_other'), 42)
# (('nursery', 'higher', 'internet', 'address', 'school', 'famsize'), 37)
# (('nursery', 'higher', 'internet', 'address', 'school', 'famsize', 'Fedu', 'Fjob_other'), 34)
# (('nursery', 'higher', 'internet', 'address', 'school', 'guardian_mother'), 25)
# (('nursery', 'higher', 'internet', 'address', 'school'), 24)
# (('nursery', 'higher', 'internet', 'address', 'school', 'Fedu'), 22)
# (('nursery', 'higher', 'internet', 'sex', 'address', 'school', 'famsize', 'absences', 'guardian_mother'), 21)
# (('famsup', 'paid', 'nursery', 'higher', 'internet', 'address', 'school', 'famsize', 'Mjob_other', 'Fjob_other', 'guardian_mother'), 19)
# (('famsup', 'paid', 'nursery', 'higher', 'internet', 'sex', 'address', 'school', 'famsize', 'reason_reputation', 'guardian_mother'), 19)
#
# Most important intersections (negative):
# (('nursery', 'higher', 'internet', 'address', 'school', 'guardian_mother'), 74)
# (('higher', 'internet', 'address', 'school', 'famsize'), 69)
# (('famsup', 'paid', 'nursery', 'higher', 'internet', 'sex', 'address', 'school', 'famsize', 'guardian_mother'), 66)
# (('famsup', 'nursery', 'higher', 'internet', 'address', 'school'), 61)
# (('famsup', 'nursery', 'higher', 'internet', 'address', 'school', 'famsize'), 57)
# (('higher', 'internet', 'address', 'school'), 55)
# (('nursery', 'higher', 'school', 'famsize', 'Fjob_other', 'guardian_mother'), 51)
# (('famsup', 'higher', 'internet', 'sex', 'address', 'school', 'famsize'), 49)
# (('famsup', 'nursery', 'higher', 'internet', 'sex', 'address', 'school', 'famsize'), 49)
# (('nursery', 'higher', 'internet', 'address', 'school', 'Fjob_other', 'guardian_mother'), 48)
#
# Best f1_macro score for binary
# 0.5592876790130795

# %% [markdown]
# # Pattern FCA

# %%
param_grid = {
    'onehot_cols': [[], students_cat_cols],
    'factorize_cols': [[]],
    'qcut_cols': [
        {},
        dict.fromkeys(students_int_cols, 2),
        dict.fromkeys(students_int_cols, 4),
    ],
    'binarize_all': [False],
}

configs = build_configs(param_grid)

methods = [
    'standard',
    'standard-support',
    'ratio-support'
]

# %%
best_pattern_config, best_pattern_intersectinos, best_pattern_score = grid_search(
    df,
    fcalc.classifier.PatternBinaryClassifier,
    y_target=students_target_variable,
    n_folds=5,
    methods=methods,
    configs=configs,
    categorical=students_cat_cols
)
# Out:
# Fitting 18 configurations
# 1
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': False}
# method='standard'
# f1_macro (mean)=0.5682156302363995
# f1_cls_1=[0.4761904761904762, 0.456140350877193, 0.5, 0.40625000000000006, 0.4528301886792452]
# f1_cls_0=[0.6526315789473683, 0.693069306930693, 0.7254901960784315, 0.5957446808510639, 0.7238095238095239]
# f1_macro=[0.5644110275689223, 0.574604828903943, 0.6127450980392157, 0.500997340425532, 0.5883198562443845]
#
# 2
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': False}
# method='standard'
# f1_macro (mean)=0.6242951347367678
# f1_cls_1=[0.5625000000000001, 0.5172413793103449, 0.47058823529411764, 0.553846153846154, 0.5357142857142857]
# f1_cls_0=[0.7021276595744682, 0.7200000000000001, 0.7476635514018691, 0.6881720430107526, 0.7450980392156863]
# f1_macro=[0.6323138297872342, 0.6186206896551725, 0.6091258933479934, 0.6210090984284533, 0.6404061624649859]
#
# 3
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': False}
# method='standard'
# f1_macro (mean)=0.5927755399789509
# f1_cls_1=[0.6229508196721312, 0.39215686274509803, 0.36, 0.4761904761904762, 0.509090909090909]
# f1_cls_0=[0.7628865979381443, 0.7102803738317757, 0.7037037037037038, 0.6526315789473685, 0.7378640776699028]
# f1_macro=[0.6929187088051377, 0.5512186182884369, 0.5318518518518519, 0.5644110275689224, 0.6234774933804059]
#
# 4
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': False}
# method='standard'
# f1_macro (mean)=0.5922272851056822
# f1_cls_1=[0.4642857142857143, 0.5, 0.509090909090909, 0.41379310344827586, 0.4528301886792452]
# f1_cls_0=[0.7058823529411764, 0.7547169811320754, 0.737864077669903, 0.66, 0.7238095238095239]
# f1_macro=[0.5850840336134453, 0.6273584905660377, 0.623477493380406, 0.536896551724138, 0.5883198562443845]
#
# 5
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': False}
# method='standard'
# f1_macro (mean)=0.5715702197575027
# f1_cls_1=[0.5142857142857143, 0.49180327868852464, 0.4918032786885246, 0.5151515151515151, 0.4444444444444445]
# f1_cls_0=[0.6136363636363636, 0.6804123711340206, 0.6804123711340205, 0.6521739130434783, 0.631578947368421]
# f1_macro=[0.563961038961039, 0.5861078249112727, 0.5861078249112726, 0.5836627140974967, 0.5380116959064327]
#
# 6
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': False}
# method='standard'
# f1_macro (mean)=0.5419597333454951
# f1_cls_1=[0.48387096774193544, 0.3846153846153846, 0.3571428571428571, 0.4307692307692308, 0.456140350877193]
# f1_cls_0=[0.6666666666666666, 0.6981132075471698, 0.6470588235294118, 0.6021505376344085, 0.693069306930693]
# f1_macro=[0.575268817204301, 0.5413642960812772, 0.5021008403361344, 0.5164598842018197, 0.574604828903943]
#
# 7
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': False}
# method='standard-support'
# f1_macro (mean)=0.2986855482889735
# f1_cls_1=[0.6260869565217391, 0.5283018867924528, 0.5688073394495413, 0.6610169491525424, 0.5233644859813084]
# f1_cls_0=[0.0, 0.038461538461538464, 0.04081632653061225, 0.0, 0.0]
# f1_macro=[0.31304347826086953, 0.28338171262699563, 0.3048118329900768, 0.3305084745762712, 0.2616822429906542]
#
# 8
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': False}
# method='standard-support'
# f1_macro (mean)=0.4570673347238957
# f1_cls_1=[0.5904761904761905, 0.5333333333333333, 0.58, 0.7047619047619047, 0.5057471264367817]
# f1_cls_0=[0.18867924528301888, 0.38235294117647056, 0.27586206896551724, 0.41509433962264153, 0.3943661971830986]
# f1_macro=[0.3895777178796047, 0.45784313725490194, 0.4279310344827586, 0.5599281221922732, 0.45005666180994014]
#
# 9
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': False}
# method='standard-support'
# f1_macro (mean)=0.34288776350934236
# f1_cls_1=[0.625, 0.5192307692307693, 0.5660377358490567, 0.6724137931034482, 0.5050505050505051]
# f1_cls_0=[0.08695652173913045, 0.07407407407407407, 0.11538461538461539, 0.09523809523809523, 0.1694915254237288]
# f1_macro=[0.35597826086956524, 0.29665242165242167, 0.34071117561683606, 0.3838259441707717, 0.33727101523711694]
#
# 10
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': False}
# method='standard-support'
# f1_macro (mean)=0.2986855482889735
# f1_cls_1=[0.6260869565217391, 0.5283018867924528, 0.5688073394495413, 0.6610169491525424, 0.5233644859813084]
# f1_cls_0=[0.0, 0.038461538461538464, 0.04081632653061225, 0.0, 0.0]
# f1_macro=[0.31304347826086953, 0.28338171262699563, 0.3048118329900768, 0.3305084745762712, 0.2616822429906542]
#
# 11
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': False}
# method='standard-support'
# f1_macro (mean)=0.34988554268309596
# f1_cls_1=[0.625, 0.5544554455445544, 0.5794392523364486, 0.6666666666666667, 0.48543689320388345]
# f1_cls_0=[0.08695652173913045, 0.21052631578947367, 0.11764705882352941, 0.13636363636363635, 0.03636363636363636]
# f1_macro=[0.35597826086956524, 0.38249088066701403, 0.348543155579989, 0.40151515151515155, 0.2609002647837599]
#
# 12
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': False}
# method='standard-support'
# f1_macro (mean)=0.3124294033477432
# f1_cls_1=[0.631578947368421, 0.5333333333333333, 0.5740740740740741, 0.6610169491525424, 0.5233644859813084]
# f1_cls_0=[0.04545454545454545, 0.07547169811320754, 0.07999999999999999, 0.0, 0.0]
# f1_macro=[0.3385167464114832, 0.30440251572327043, 0.327037037037037, 0.3305084745762712, 0.2616822429906542]
#
# 13
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': False}
# method='ratio-support'
# f1_macro (mean)=0.5746846394550704
# f1_cls_1=[0.6172839506172839, 0.5217391304347826, 0.5866666666666667, 0.5316455696202531, 0.5070422535211269]
# f1_cls_0=[0.5974025974025974, 0.6292134831460675, 0.6265060240963857, 0.5316455696202531, 0.5977011494252873]
# f1_macro=[0.6073432740099407, 0.575476306790425, 0.6065863453815261, 0.5316455696202531, 0.552371701473207]
#
# 14
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': False}
# method='ratio-support'
# f1_macro (mean)=0.5151670933942254
# f1_cls_1=[0.673469387755102, 0.5411764705882353, 0.5714285714285714, 0.7216494845360825, 0.4705882352941177]
# f1_cls_0=[0.46666666666666673, 0.4657534246575343, 0.3, 0.5573770491803278, 0.3835616438356165]
# f1_macro=[0.5700680272108843, 0.5034649476228847, 0.4357142857142857, 0.6395132668582051, 0.4270749395648671]
#
# 15
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': False}
# method='ratio-support'
# f1_macro (mean)=0.556798601935262
# f1_cls_1=[0.6666666666666667, 0.48101265822784806, 0.5842696629213483, 0.6593406593406593, 0.5405405405405405]
# f1_cls_0=[0.5588235294117647, 0.48101265822784806, 0.463768115942029, 0.5373134328358209, 0.5952380952380952]
# f1_macro=[0.6127450980392157, 0.48101265822784806, 0.5240188894316886, 0.5983270460882402, 0.5678893178893178]
#
# 16
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {}, 'binarize_all': False}
# method='ratio-support'
# f1_macro (mean)=0.5988217417649613
# f1_cls_1=[0.5753424657534246, 0.6376811594202899, 0.5151515151515151, 0.48648648648648646, 0.5454545454545454]
# f1_cls_0=[0.6352941176470588, 0.7191011235955056, 0.6521739130434783, 0.5476190476190476, 0.6739130434782609]
# f1_macro=[0.6053182917002418, 0.6783911415078978, 0.5836627140974967, 0.517052767052767, 0.6096837944664031]
#
# 17
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': False}
# method='ratio-support'
# f1_macro (mean)=0.5283964123542174
# f1_cls_1=[0.5957446808510638, 0.5316455696202532, 0.5882352941176471, 0.6666666666666666, 0.5060240963855421]
# f1_cls_0=[0.40625, 0.5316455696202532, 0.5205479452054795, 0.48387096774193555, 0.4533333333333333]
# f1_macro=[0.5009973404255319, 0.5316455696202532, 0.5543916196615633, 0.5752688172043011, 0.4796787148594377]
#
# 18
# classifier=<class 'fcalc.classifier.PatternBinaryClassifier'>
# config={'onehot_cols': ['Mjob', 'Fjob', 'reason', 'guardian'], 'factorize_cols': [], 'qcut_cols': {'age': 4, 'Medu': 4, 'Fedu': 4, 'traveltime': 4, 'studytime': 4, 'failures': 4, 'famrel': 4, 'freetime': 4, 'goout': 4, 'Dalc': 4, 'Walc': 4, 'health': 4, 'absences': 4}, 'binarize_all': False}
# method='ratio-support'
# f1_macro (mean)=0.580413757391871
# f1_cls_1=[0.6585365853658538, 0.4788732394366197, 0.547945205479452, 0.6373626373626373, 0.5352112676056338]
# f1_cls_0=[0.6315789473684211, 0.5747126436781609, 0.611764705882353, 0.5074626865671642, 0.6206896551724139]
# f1_macro=[0.6450577663671375, 0.5267929415573903, 0.5798549556809025, 0.5724126619649008, 0.5779504613890238]

# %%
print("Best config for binary")
print(best_pattern_config)
print()
print("Most important intersections (positive):")
print("\n".join(map(str, best_pattern_intersectinos[0].most_common(10))))
print()
print("Most important intersections (negative):")
print("\n".join(map(str, best_pattern_intersectinos[1].most_common(10))))
print()
print("Best f1_macro score for binary")
print(best_pattern_score)
# Out:
# Best config for binary
# ('standard', {'onehot_cols': [], 'factorize_cols': [], 'qcut_cols': {'age': 2, 'Medu': 2, 'Fedu': 2, 'traveltime': 2, 'studytime': 2, 'failures': 2, 'famrel': 2, 'freetime': 2, 'goout': 2, 'Dalc': 2, 'Walc': 2, 'health': 2, 'absences': 2}, 'binarize_all': False})
#
# Most important intersections (positive):
# (('schoolsup', 'nursery', 'higher', 'internet', 'romantic', 'sex', 'address', 'school', 'Pstatus', 'age', 'Fedu', 'studytime', 'famrel', 'goout', 'Walc', 'Fjob'), 4)
# (('schoolsup', 'famsup', 'paid', 'nursery', 'higher', 'internet', 'sex', 'address', 'school', 'famsize', 'age', 'famrel', 'goout', 'Walc', 'absences'), 4)
# (('schoolsup', 'famsup', 'paid', 'higher', 'internet', 'sex', 'address', 'school', 'Pstatus', 'age', 'Medu', 'Fedu', 'studytime', 'goout', 'health'), 4)
# (('schoolsup', 'paid', 'nursery', 'higher', 'internet', 'romantic', 'sex', 'address', 'school', 'famsize', 'Pstatus', 'age', 'Fedu', 'studytime', 'freetime', 'goout', 'Walc', 'absences'), 4)
# (('schoolsup', 'paid', 'higher', 'internet', 'address', 'school', 'famsize', 'Pstatus', 'famrel', 'freetime', 'goout', 'Walc'), 4)
# (('schoolsup', 'nursery', 'higher', 'romantic', 'school', 'famsize', 'goout', 'Walc', 'health', 'Mjob'), 4)
# (('nursery', 'higher', 'romantic', 'school', 'famsize', 'Pstatus', 'age', 'Medu', 'studytime', 'freetime', 'goout', 'Walc', 'health', 'Fjob'), 4)
# (('schoolsup', 'nursery', 'higher', 'internet', 'romantic', 'address', 'school', 'famsize', 'age', 'Fedu', 'studytime', 'freetime', 'goout', 'Walc', 'health', 'absences'), 4)
# (('schoolsup', 'paid', 'nursery', 'higher', 'romantic', 'sex', 'address', 'school', 'famsize', 'Pstatus', 'age', 'Fedu', 'studytime', 'freetime', 'goout', 'Walc', 'absences'), 4)
# (('schoolsup', 'famsup', 'paid', 'nursery', 'higher', 'romantic', 'sex', 'address', 'school', 'famsize', 'Pstatus', 'age', 'Medu', 'studytime', 'famrel', 'freetime', 'goout', 'Walc', 'absences', 'Mjob', 'Fjob'), 4)
#
# Most important intersections (negative):
# (('schoolsup', 'nursery', 'higher', 'romantic', 'sex', 'school', 'famsize', 'Fedu', 'famrel', 'freetime', 'Walc', 'reason', 'guardian'), 4)
# (('famsup', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'school', 'famsize', 'Pstatus', 'age', 'Medu', 'health', 'Mjob', 'reason', 'guardian'), 4)
# (('schoolsup', 'paid', 'higher', 'internet', 'romantic', 'address', 'school', 'Pstatus', 'age', 'studytime', 'famrel', 'freetime', 'goout', 'Walc', 'health', 'reason'), 4)
# (('famsup', 'paid', 'higher', 'internet', 'romantic', 'sex', 'school', 'famsize', 'Pstatus', 'age', 'Medu', 'famrel', 'freetime', 'goout', 'health', 'Mjob', 'guardian'), 4)
# (('schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'sex', 'school', 'age', 'Fedu', 'freetime', 'goout', 'Walc', 'health', 'reason', 'guardian'), 4)
# (('famsup', 'nursery', 'higher', 'internet', 'romantic', 'sex', 'school', 'age', 'Medu', 'Fedu', 'famrel', 'freetime', 'guardian'), 4)
# (('paid', 'activities', 'nursery', 'higher', 'internet', 'sex', 'school', 'famsize', 'age', 'Medu', 'freetime', 'Walc', 'guardian'), 4)
# (('schoolsup', 'famsup', 'higher', 'internet', 'sex', 'address', 'school', 'famsize', 'Pstatus', 'age', 'Medu', 'famrel', 'freetime', 'health', 'absences', 'guardian'), 4)
# (('activities', 'nursery', 'higher', 'internet', 'romantic', 'school', 'famsize', 'Pstatus', 'age', 'studytime', 'famrel', 'goout', 'Walc', 'reason', 'guardian'), 4)
# (('schoolsup', 'famsup', 'paid', 'nursery', 'higher', 'internet', 'romantic', 'sex', 'address', 'school', 'famsize', 'Pstatus', 'age', 'Medu', 'Fedu', 'studytime', 'famrel', 'goout', 'Walc', 'health', 'Fjob', 'reason', 'guardian'), 4)
#
# Best f1_macro score for binary
# 0.6242951347367678
